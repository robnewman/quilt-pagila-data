# %%
# Setup

import psycopg2
import pandas as pd

# %%
# Localhost PostgreSQL

host = "localhost"
database = "postgres"
user = "postgres"
passw = ""

# %%
# Connection string
conn_str = "host={} dbname={} user={} password={}".format(host, database, user, passw)

# %%
# Connect
connection = psycopg2.connect(conn_str)

# %%
# Initial query
q1 = 'SELECT * FROM payment'

# %%
# "Cold server, cold client"
df = pd.read_sql(q1, con=connection)

# %%
# Iteration 1
df_1 = pd.read_sql(q1, con=connection)

# %%
# Iteration 2
df_2 = pd.read_sql(q1, con=connection)

# %%
# Iteration 3
df_3 = pd.read_sql(q1, con=connection)

# %%
# FULL OUTER JOIN query
q_outer_join = 'SELECT * FROM payment p \
    FULL OUTER JOIN \
    customer c ON p.customer_id = c.customer_id \
    FULL OUTER JOIN \
    store s ON c.store_id = s.store_id \
    FULL OUTER JOIN \
    address a ON a.address_id = c.address_id \
    FULL OUTER JOIN \
    rental r ON p.rental_id = r.rental_id'

# %%
# FULL OUTER JOIN query result
df_outer_join = pd.read_sql(q_outer_join, con=connection)

# %%
# Display results
df_outer_join
# Out:
#        payment_id  customer_id  staff_id rental_id  amount  \
# 0         16050.0        269.0       2.0       7.0    1.99
# 1         16051.0        269.0       1.0      98.0    0.99
# 2         16052.0        269.0       2.0     678.0    6.99
# 3         16053.0        269.0       2.0     703.0    0.99
# 4         16054.0        269.0       1.0     750.0    4.99
# 5         16055.0        269.0       2.0    1099.0    2.99
# 6         16056.0        270.0       1.0     193.0    1.99
# 7         16057.0        270.0       1.0    1040.0    4.99
# 8         16058.0        271.0       1.0    1096.0    8.99
# 9         16059.0        272.0       1.0      33.0    0.99
# 10        16060.0        272.0       1.0     405.0    6.99
# 11        16061.0        272.0       1.0    1041.0    6.99
# 12        16062.0        272.0       1.0    1072.0    0.99
# 13        16063.0        273.0       2.0     122.0    3.99
# 14        16064.0        273.0       2.0     980.0    0.99
# ...
