# %%
import psycopg2
import pandas as pd

# %%
# 1. Using SQL

host = "localhost"
database = "postgres"
user = "postgres"
passw = ""

# %%
conn_str = "host={} dbname={} user={} password={}".format(host, database, user, passw)

# %%
connection = psycopg2.connect(conn_str)

# %%
q1 = 'SELECT * FROM payment'

# %%
q2 = 'SELECT last_name, count(last_name) FROM actor GROUP BY  last_name'

# %%
q3 = 'SELECT * FROM payment p FULL OUTER JOIN customer c ON p.customer_id = c.customer_id'

# %%
df = pd.read_sql(q1, con=connection)

# %%
df
# Out:
#        payment_id  customer_id  staff_id  rental_id  amount  \
# 0           16050          269         2          7    1.99
# 1           16051          269         1         98    0.99
# 2           16052          269         2        678    6.99
# 3           16053          269         2        703    0.99
# 4           16054          269         1        750    4.99
# 5           16055          269         2       1099    2.99
# 6           16056          270         1        193    1.99
# 7           16057          270         1       1040    4.99
# 8           16058          271         1       1096    8.99
# 9           16059          272         1         33    0.99
# 10          16060          272         1        405    6.99
# 11          16061          272         1       1041    6.99
# 12          16062          272         1       1072    0.99
# 13          16063          273         2        122    3.99
# 14          16064          273         2        980    0.99
# ...
