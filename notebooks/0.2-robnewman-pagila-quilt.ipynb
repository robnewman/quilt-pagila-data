# %%
import pandas as pd

# %%
from quilt.data.robnewman import performance

# %%
performance.payments()
# Out:
#        payment_id  customer_id  staff_id  rental_id  amount  \
# 0           16050          269         2          7    1.99
# 1           16051          269         1         98    0.99
# 2           16052          269         2        678    6.99
# 3           16053          269         2        703    0.99
# 4           16054          269         1        750    4.99
# 5           16055          269         2       1099    2.99
# 6           16056          270         1        193    1.99
# 7           16057          270         1       1040    4.99
# 8           16058          271         1       1096    8.99
# 9           16059          272         1         33    0.99
# 10          16060          272         1        405    6.99
# 11          16061          272         1       1041    6.99
# 12          16062          272         1       1072    0.99
# 13          16063          273         2        122    3.99
# 14          16064          273         2        980    0.99
# ...

# %%
df_1 = performance.payments()

# %%
df_2 = performance.payments()

# %%
df_3 = performance.payments()

# %%
# FULL OUTER JOIN query
df_outer_join = performance.payments_outer_join()

# %%
# Display results
df_outer_join
# Out:
#        payment_id  customer_id  staff_id  rental_id  amount  \
# 0           16050          269         2          7    1.99
# 1           16051          269         1         98    0.99
# 2           16052          269         2        678    6.99
# 3           16053          269         2        703    0.99
# 4           16054          269         1        750    4.99
# 5           16055          269         2       1099    2.99
# 6           16056          270         1        193    1.99
# 7           16057          270         1       1040    4.99
# 8           16058          271         1       1096    8.99
# 9           16059          272         1         33    0.99
# 10          16060          272         1        405    6.99
# 11          16061          272         1       1041    6.99
# 12          16062          272         1       1072    0.99
# 13          16063          273         2        122    3.99
# 14          16064          273         2        980    0.99
# ...

# %%
# FULL OUTER JOIN query result
df_outer_join = performance.payments_large_outer_join()

# %%
df_outer_join
# Out:
#        payment_id  customer_id  staff_id  rental_id  amount  \
# 0         16050.0        269.0       2.0        7.0    1.99
# 1         16051.0        269.0       1.0       98.0    0.99
# 2         16052.0        269.0       2.0      678.0    6.99
# 3         16053.0        269.0       2.0      703.0    0.99
# 4         16054.0        269.0       1.0      750.0    4.99
# 5         16055.0        269.0       2.0     1099.0    2.99
# 6         16056.0        270.0       1.0      193.0    1.99
# 7         16057.0        270.0       1.0     1040.0    4.99
# 8         16058.0        271.0       1.0     1096.0    8.99
# 9         16059.0        272.0       1.0       33.0    0.99
# 10        16060.0        272.0       1.0      405.0    6.99
# 11        16061.0        272.0       1.0     1041.0    6.99
# 12        16062.0        272.0       1.0     1072.0    0.99
# 13        16063.0        273.0       2.0      122.0    3.99
# 14        16064.0        273.0       2.0      980.0    0.99
# ...
